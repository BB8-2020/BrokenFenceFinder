# %%
import numpy as np
import cv2

# %%
red, blue, green = (0,0,255), (255,0,0), (0,255,0)

# %% [markdown]
# ## Default

# %%
image = cv2.imread('fence.png')

# %%
imggray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
ret, thresh = cv2.threshold(imggray, 127, 255, 0)
contours, hierarchy = cv2.findContours(thresh, cv2.RETR_CCOMP, cv2.CHAIN_APPROX_SIMPLE)

# %%
img = cv2.drawContours(image, contours, -1, (0,255,0), 2)

# %%
cv2.imwrite('test.png', img)
# Out:
# True

# %%
# load the query image, compute the ratio of the old height
# to the new height, clone it, and resize it
image = cv2.imread('fence.png')
# convert the image to grayscale, blur it, and find edges
# in the image
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
gray = cv2.bilateralFilter(gray, 11, 17, 17)
edged = cv2.Canny(gray, 30, 200)

# %%
cv2.imwrite('bilateralfilterd.png', edged)
# Out:
# True

# %%
contours, hierarchy = cv2.findContours(edged, cv2.RETR_CCOMP, cv2.CHAIN_APPROX_SIMPLE)

# %%
img = cv2.drawContours(image, contours, -1, (0,0,255), 2)

# %%
cv2.imwrite('test2.png', img)
# Out:
# True

# %% [markdown]
# ## Search for squares

# %%
areaSum = 0
for cnt in contours:
    areaSum += cv2.contourArea(cnt)
meanArea = areaSum / len(contours)

# %%
image = cv2.imread('fence.png')

# %%
min_rect_len = 1
max_rect_len = 3
for contour in contours:
    (x, y, w, h) = cv2.boundingRect(contour)
    if h>min_rect_len and w>min_rect_len:
        cv2.rectangle(image, (x, y), (x + w, y + h), red, 1)

# %%
cv2.imwrite('test3.png', image)
# Out:
# True

# %% [markdown]
# ## Online example (disco colors)

# %% [markdown]
# https://docs.opencv.org/3.4/d5/daa/tutorial_js_contours_begin.html
